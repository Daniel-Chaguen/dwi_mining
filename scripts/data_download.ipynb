# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Instalacion de cli de aws

# %%
# !curl "https://awscli.amazonaws.com/awscli-exe-linux-x86_64.zip" -o "awscliv2.zip"
# !unzip awscliv2.zip
# !sudo ./aws/install
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   inflating: aws/dist/awscli/examples/codecommit/untag-resource.rst
#   inflating: aws/dist/awscli/examples/codecommit/get-pull-request-approval-states.rst
#   inflating: aws/dist/awscli/examples/codecommit/get-blob.rst
#   inflating: aws/dist/awscli/examples/codecommit/put-comment-reaction.rst
#   inflating: aws/dist/awscli/examples/codecommit/delete-repository.rst
#   inflating: aws/dist/awscli/examples/codecommit/test-repository-triggers.rst
#   inflating: aws/dist/awscli/examples/codecommit/update-approval-rule-template-content.rst
#   inflating: aws/dist/awscli/examples/codecommit/describe-merge-conflicts.rst
#   inflating: aws/dist/awscli/examples/codecommit/batch-describe-merge-conflicts.rst
#   inflating: aws/dist/awscli/examples/codecommit/delete-pull-request-approval-rule.rst
#   inflating: aws/dist/awscli/examples/codecommit/get-branch.rst
#   inflating: aws/dist/awscli/examples/codecommit/delete-branch.rst
# ...

# %%
path_to_save_dataset = "/content/drive/add_own_path"

# %%
# !aws --version
# Out:
# aws-cli/2.31.33 Python/3.13.9 Linux/6.6.105+ exe/x86_64.ubuntu.22

# %%
# !mkdir -p $path_to_save_dataset
# !aws s3 sync --no-sign-request s3://openneuro.org/ds000030 $path_to_save_dataset
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# download: s3://openneuro.org/ds000030/sub-10629/func/sub-10629_task-bart_bold.json to drive/MyDrive/Colab_Notebooks/minería/datos_dwi/sub-10629/func/sub-10629_task-bart_bold.json
# download: s3://openneuro.org/ds000030/sub-10629/func/sub-10629_task-bart_events.tsv to drive/MyDrive/Colab_Notebooks/minería/datos_dwi/sub-10629/func/sub-10629_task-bart_events.tsv
# download: s3://openneuro.org/ds000030/sub-10629/func/sub-10629_task-bht_bold.json to drive/MyDrive/Colab_Notebooks/minería/datos_dwi/sub-10629/func/sub-10629_task-bht_bold.json
# download: s3://openneuro.org/ds000030/sub-10624/func/sub-10624_task-bht_bold.nii.gz to drive/MyDrive/Colab_Notebooks/minería/datos_dwi/sub-10624/func/sub-10624_task-bht_bold.nii.gz
# download: s3://openneuro.org/ds000030/sub-10629/func/sub-10629_task-bht_events.tsv to drive/MyDrive/Colab_Notebooks/minería/datos_dwi/sub-10629/func/sub-10629_task-bht_events.tsv
# ...
